# %%
library(tidyverse)
library(tidymodels)
library(gridExtra)

set.seed(5)

# %%
water_train <- read_csv("train.csv")
water_train
# Out:
# Rows: 18722 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): DHSID_EA, cname, urban, path
# dbl (9): year, lat, lon, n_asset, asset_index, n_water, water_index, cluster...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#       DHSID_EA           cname year lat       lon      n_asset asset_index
# 1     IA-2015-7-00010004 IA    2015  9.165413 92.74270 22       2.6507682
# 2     IA-2015-7-00010005 IA    2015  8.307356 93.09379 22       2.1577842
# 3     IA-2015-7-00010007 IA    2015  7.016968 93.89323 21       1.8327508
# 4     IA-2015-7-00010016 IA    2015  9.194938 92.80043 22       2.7460958
# 5     IA-2015-7-00010018 IA    2015  8.055606 93.54389 22       2.5818691
# 6     IA-2015-7-00010021 IA    2015  9.200117 92.79910 22       2.6062020
# ...

# %%
water_test <- read.csv("test_masked.csv")
water_test
# Out:
#      DHSID_EA           cname year lat       lon      n_asset asset_index
# 1    IA-2015-7-00010009 IA    2015  9.220903 92.78153 22       2.7218117
# 2    IA-2015-7-00010011 IA    2015  7.028410 93.88343 20       2.2872791
# 3    IA-2015-7-00010017 IA    2015 12.371448 92.78366 22       0.6771093
# 4    IA-2015-7-00010044 IA    2015 11.727304 92.71926 21       1.7936830
# 5    IA-2015-7-00010060 IA    2015  9.185310 92.77764 22       2.7581683
# 6    IA-2015-7-00010072 IA    2015 13.258593 92.98648 17       2.3155383
# 7    IA-2015-7-00010074 IA    2015  7.994928 93.53420 22       2.6183560
# 8    IA-2015-7-00010099 IA    2015 11.674596 92.73615 22       2.9784625
# 9    IA-2015-7-00010109 IA    2015 12.732847 92.87783 20      -0.2764167
# 10   IA-2015-7-00010168 IA    2015 12.648469 92.91331 22       1.2412420
# 11   IA-2015-7-00010172 IA    2015  9.170954 92.74544 22       2.5461798
# 12   IA-2015-7-00020001 IA    2015 14.467227 77.69836 22       1.4903592
# ...

# %%
# lm_spec <- linear_reg(mode = "regression", engine = "lm", penalty = NULL, mixture = NULL)

lm_spec <- linear_reg() |>
  set_engine("lm") |>
  set_mode("regression")

lm_recipe <- recipe(water_index ~ asset_index, data = water_train)

lm_fit <- workflow() |>
  add_recipe(lm_recipe) |>
  add_model(lm_spec) |>
  fit(data = water_train)

lm_fit
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: linear_reg()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 0 Recipe Steps
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# stats::lm(formula = ..y ~ ., data = data)
#
# Coefficients:
# (Intercept)  asset_index
#      3.7727       0.3703
